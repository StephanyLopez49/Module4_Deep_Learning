# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to C:\Users\User\AppData\Local\Temp\pip-req-build-4wuplzsr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from mnist1d==0.0.2.post16) (2.34.2)
# Requirement already satisfied: numpy in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from mnist1d==0.0.2.post16) (2.4.6)
# Requirement already satisfied: matplotlib in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from mnist1d==0.0.2.post16) (3.10.9)
# Collecting scipy (from mnist1d==0.0.2.post16)
#   Downloading scipy-1.18.0-cp313-cp313-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\User\Desktop\Módulo 4\modulo4\Lib\site-packages (from requests->mnist1d==0.0.2.post16) (2026.5.20)
# Downloading scipy-1.18.0-cp313-cp313-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.6 MB 6.2 MB/s eta 0:00:06
#    --- ------------------------------------ 2.9/36.6 MB 8.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.7/36.6 MB 8.6 MB/s eta 0:00:04
#    ------- -------------------------------- 6.6/36.6 MB 8.7 MB/s eta 0:00:04
#    --------- ------------------------------ 8.7/36.6 MB 8.9 MB/s eta 0:00:04
#    ------------ --------------------------- 11.5/36.6 MB 9.8 MB/s eta 0:00:03
#    --------------- ------------------------ 14.4/36.6 MB 10.2 MB/s eta 0:00:03
#    ------------------ --------------------- 16.5/36.6 MB 10.2 MB/s eta 0:00:02
#    -------------------- ------------------- 18.9/36.6 MB 10.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.0/36.6 MB 10.3 MB/s eta 0:00:02
#    ------------------------- -------------- 23.1/36.6 MB 10.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 25.7/36.6 MB 10.4 MB/s eta 0:00:02
#    ------------------------------ --------- 28.3/36.6 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 30.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.5/36.6 MB 10.5 MB/s eta 0:00:01
#    -------------------------------------- - 34.9/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 7.7 MB/s  0:00:04
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml): started
#   Building wheel for mnist1d (pyproject.toml): finished with status 'done'
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=16027 sha256=ab428219017ff4a629deeb991b1de7d95bc678f9fcec9a49374fbf30d8db4eed
#   Stored in directory: C:\Users\User\AppData\Local\Temp\pip-ephem-wheel-cache-bs26fovc\wheels\33\99\c5\794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: scipy, mnist1d
#
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    -------------------- ------------------- 1/2 [mnist1d]
#    ---------------------------------------- 2/2 [mnist1d]
#
# Successfully installed mnist1d-0.0.2.post16 scipy-1.18.0
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d 'C:\Users\User\AppData\Local\Temp\pip-req-build-4wuplzsr'

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# Datos
D_i = 40
D_o = 40

model = nn.Sequential(
    
    # 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
    nn.Conv1d(
        in_channels=1,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(), # 2. ReLU

    # 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(), # 4. ReLU

    # 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(), # 6. ReLU

    # 7. Aplanamiento (convierte 4x15) a longitud 60
    nn.Flatten(),

    # 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
    nn.Linear(60, 10)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.869261, training error 73.80, validation loss 1.897911, validation error 76.50
# Epoch     1, training loss 1.547971, training error 61.45, validation loss 1.576813, validation error 63.40
# Epoch     2, training loss 1.399790, training error 56.25, validation loss 1.418988, validation error 57.60
# Epoch     3, training loss 1.270585, training error 51.60, validation loss 1.294618, validation error 55.10
# Epoch     4, training loss 1.191483, training error 48.45, validation loss 1.212462, validation error 51.00
# Epoch     5, training loss 1.073570, training error 42.85, validation loss 1.115025, validation error 46.70
# Epoch     6, training loss 1.024148, training error 42.45, validation loss 1.090067, validation error 46.20
# Epoch     7, training loss 0.971919, training error 40.12, validation loss 1.018079, validation error 41.60
# Epoch     8, training loss 0.902566, training error 36.33, validation loss 0.947730, validation error 39.00
# Epoch     9, training loss 0.840664, training error 35.35, validation loss 0.907299, validation error 39.20
# Epoch    10, training loss 0.745923, training error 30.82, validation loss 0.821202, validation error 33.10
# Epoch    11, training loss 0.707488, training error 28.43, validation loss 0.760599, validation error 31.50
# Epoch    12, training loss 0.663154, training error 25.18, validation loss 0.723486, validation error 28.20
# Epoch    13, training loss 0.618478, training error 24.50, validation loss 0.707151, validation error 27.40
# Epoch    14, training loss 0.598167, training error 22.88, validation loss 0.685666, validation error 25.90
# Epoch    15, training loss 0.535562, training error 20.70, validation loss 0.634871, validation error 24.80
# Epoch    16, training loss 0.488467, training error 18.78, validation loss 0.581499, validation error 21.20
# Epoch    17, training loss 0.506161, training error 17.65, validation loss 0.596709, validation error 21.20
# Epoch    18, training loss 0.382418, training error 14.00, validation loss 0.508912, validation error 18.40
# Epoch    19, training loss 0.365152, training error 13.80, validation loss 0.503377, validation error 18.10
# Epoch    20, training loss 0.293149, training error 9.97, validation loss 0.456649, validation error 15.20
# Epoch    21, training loss 0.278477, training error 10.03, validation loss 0.463149, validation error 15.50
# Epoch    22, training loss 0.257217, training error 8.80, validation loss 0.455067, validation error 14.70
# Epoch    23, training loss 0.236415, training error 8.30, validation loss 0.428702, validation error 14.00
# Epoch    24, training loss 0.213243, training error 7.30, validation loss 0.421925, validation error 12.60
# Epoch    25, training loss 0.223054, training error 7.85, validation loss 0.418452, validation error 13.30
# Epoch    26, training loss 0.177796, training error 5.65, validation loss 0.384970, validation error 12.10
# Epoch    27, training loss 0.175067, training error 5.97, validation loss 0.399680, validation error 11.90
# Epoch    28, training loss 0.180138, training error 6.10, validation loss 0.402470, validation error 11.10
# Epoch    29, training loss 0.233095, training error 8.78, validation loss 0.485797, validation error 14.10
# Epoch    30, training loss 0.155361, training error 5.12, validation loss 0.398017, validation error 12.00
# Epoch    31, training loss 0.145651, training error 4.95, validation loss 0.370469, validation error 10.50
# Epoch    32, training loss 0.140885, training error 4.90, validation loss 0.384169, validation error 11.60
# Epoch    33, training loss 0.142957, training error 4.68, validation loss 0.393329, validation error 11.90
# Epoch    34, training loss 0.185792, training error 6.57, validation loss 0.460748, validation error 13.30
# Epoch    35, training loss 0.129505, training error 4.50, validation loss 0.377154, validation error 10.60
# Epoch    36, training loss 0.133983, training error 4.32, validation loss 0.422660, validation error 11.10
# Epoch    37, training loss 0.108741, training error 3.40, validation loss 0.391478, validation error 11.30
# Epoch    38, training loss 0.130843, training error 4.97, validation loss 0.386711, validation error 10.30
# Epoch    39, training loss 0.128630, training error 5.05, validation loss 0.418247, validation error 11.30
# Epoch    40, training loss 0.091162, training error 2.30, validation loss 0.380385, validation error 10.70
# Epoch    41, training loss 0.085576, training error 2.57, validation loss 0.374153, validation error 10.00
# Epoch    42, training loss 0.081035, training error 2.22, validation loss 0.367495, validation error 10.40
# Epoch    43, training loss 0.080350, training error 2.22, validation loss 0.391228, validation error 10.30
# Epoch    44, training loss 0.081611, training error 2.55, validation loss 0.399720, validation error 10.50
# Epoch    45, training loss 0.089641, training error 3.05, validation loss 0.421438, validation error 10.80
# Epoch    46, training loss 0.080708, training error 2.40, validation loss 0.390992, validation error 10.60
# Epoch    47, training loss 0.077144, training error 2.28, validation loss 0.418384, validation error 10.90
# Epoch    48, training loss 0.072848, training error 2.12, validation loss 0.396753, validation error 10.00
# Epoch    49, training loss 0.068509, training error 1.65, validation loss 0.398945, validation error 10.30
# Epoch    50, training loss 0.069283, training error 1.97, validation loss 0.403412, validation error 10.10
# Epoch    51, training loss 0.065435, training error 1.78, validation loss 0.417000, validation error 10.10
# Epoch    52, training loss 0.069718, training error 2.03, validation loss 0.417516, validation error 10.90
# Epoch    53, training loss 0.065668, training error 1.97, validation loss 0.415019, validation error 10.70
# Epoch    54, training loss 0.062955, training error 1.75, validation loss 0.415782, validation error 9.90
# Epoch    55, training loss 0.070624, training error 2.22, validation loss 0.425563, validation error 10.70
# Epoch    56, training loss 0.064055, training error 1.72, validation loss 0.436339, validation error 10.90
# Epoch    57, training loss 0.063718, training error 1.97, validation loss 0.433556, validation error 10.70
# Epoch    58, training loss 0.055931, training error 1.50, validation loss 0.442416, validation error 11.10
# Epoch    59, training loss 0.059738, training error 1.62, validation loss 0.431775, validation error 10.90
# Epoch    60, training loss 0.052617, training error 1.38, validation loss 0.436387, validation error 10.80
# Epoch    61, training loss 0.049612, training error 1.10, validation loss 0.431647, validation error 10.80
# Epoch    62, training loss 0.049535, training error 1.18, validation loss 0.438001, validation error 10.50
# Epoch    63, training loss 0.048601, training error 1.07, validation loss 0.436435, validation error 10.30
# Epoch    64, training loss 0.048211, training error 0.95, validation loss 0.437987, validation error 10.90
# Epoch    65, training loss 0.047693, training error 1.07, validation loss 0.441804, validation error 11.00
# Epoch    66, training loss 0.047946, training error 1.03, validation loss 0.439543, validation error 11.30
# Epoch    67, training loss 0.047404, training error 1.10, validation loss 0.445195, validation error 10.70
# Epoch    68, training loss 0.046130, training error 0.97, validation loss 0.443702, validation error 11.00
# Epoch    69, training loss 0.046273, training error 0.93, validation loss 0.447466, validation error 11.00
# Epoch    70, training loss 0.048288, training error 1.18, validation loss 0.454817, validation error 10.70
# Epoch    71, training loss 0.044194, training error 1.00, validation loss 0.448446, validation error 11.30
# Epoch    72, training loss 0.044573, training error 0.90, validation loss 0.453675, validation error 11.30
# Epoch    73, training loss 0.043126, training error 0.90, validation loss 0.459219, validation error 10.70
# Epoch    74, training loss 0.046215, training error 1.15, validation loss 0.466079, validation error 11.30
# Epoch    75, training loss 0.042421, training error 0.72, validation loss 0.459887, validation error 11.10
# Epoch    76, training loss 0.044412, training error 1.05, validation loss 0.461864, validation error 11.20
# Epoch    77, training loss 0.042204, training error 0.78, validation loss 0.469608, validation error 10.80
# Epoch    78, training loss 0.041822, training error 0.85, validation loss 0.463838, validation error 11.20
# Epoch    79, training loss 0.041196, training error 0.75, validation loss 0.468395, validation error 11.30
# Epoch    80, training loss 0.039761, training error 0.78, validation loss 0.459856, validation error 11.00
# Epoch    81, training loss 0.039651, training error 0.80, validation loss 0.461212, validation error 10.80
# Epoch    82, training loss 0.038726, training error 0.68, validation loss 0.465614, validation error 11.00
# Epoch    83, training loss 0.038444, training error 0.68, validation loss 0.462579, validation error 11.30
# Epoch    84, training loss 0.038280, training error 0.62, validation loss 0.466820, validation error 10.90
# Epoch    85, training loss 0.038138, training error 0.68, validation loss 0.461099, validation error 11.00
# Epoch    86, training loss 0.037657, training error 0.65, validation loss 0.466346, validation error 11.00
# Epoch    87, training loss 0.038060, training error 0.57, validation loss 0.470672, validation error 11.20
# Epoch    88, training loss 0.038537, training error 0.70, validation loss 0.465714, validation error 11.00
# Epoch    89, training loss 0.037155, training error 0.57, validation loss 0.470589, validation error 11.10
# Epoch    90, training loss 0.037712, training error 0.68, validation loss 0.472617, validation error 11.10
# Epoch    91, training loss 0.038686, training error 0.72, validation loss 0.466933, validation error 11.10
# Epoch    92, training loss 0.037239, training error 0.57, validation loss 0.472094, validation error 11.10
# Epoch    93, training loss 0.036624, training error 0.60, validation loss 0.472314, validation error 10.90
# Epoch    94, training loss 0.036102, training error 0.57, validation loss 0.472021, validation error 11.10
# Epoch    95, training loss 0.035994, training error 0.53, validation loss 0.475659, validation error 11.10
# Epoch    96, training loss 0.036364, training error 0.57, validation loss 0.476845, validation error 11.30
# Epoch    97, training loss 0.035942, training error 0.65, validation loss 0.472289, validation error 10.90
# Epoch    98, training loss 0.036024, training error 0.60, validation loss 0.477405, validation error 11.30
# Epoch    99, training loss 0.035052, training error 0.53, validation loss 0.476172, validation error 11.20

# %% [markdown]
# # A R C H I T E C T U R E
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# La red convolucional mostró una convergencia adecuada durante el entrenamiento. El error de entrenamiento disminuyó del 72.47% al 1.22%, mientras que el error de validación se redujo del 74.30% al 10.40%.
#
# El menor error de validación se alcanzó alrededor de la época 67 (10.20%), tras lo cual las métricas se estabilizaron sin mejoras significativas adicionales.
#
# Estos resultados indican que el modelo logró aprender correctamente las características de las señales MNIST-1D. La diferencia entre el error de entrenamiento (1.22%) y el de validación (10.40%) refleja un ligero sobreajuste, esperable dado el tamaño reducido del conjunto de datos, pero no lo suficientemente marcado como para comprometer la capacidad de generalización del modelo.
